# %%
num = int(input("Enter a number: ")) #) Write a Python program to check if a number is positive, negative or zero.
if num > 0:
    print("+ve")
elif num < 0:
    print("-ve")
else:
  print("Zero")
# Out:
# Enter a number:  2
# +ve

# %%
from math import factorial

# %%
factorial(5)
# Out:
# 120

# %%
# how memory managed in python?

# %%
x = 10
y = 10
z = 20
p = 10

# %%
print(id(x))
# Out:
# 140735504667848

# %%
print(id(y))
# Out:
# 140735504667848

# %%
print(id(z)) # 4 bytes
# Out:
# 140735504668168

# %%
print(id(p))
# Out:
# 140735504667848
